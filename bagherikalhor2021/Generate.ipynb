# %%
import scipy
from tqdm import tqdm
from scipy import optimize
import numpy as np
import pandas as pd
from tqdm import tqdm
import pandas_ta as ta
import yfinance as yf
from time import time
from copy import deepcopy
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# ## Application:
# ### Financial Crisis in the Framework of Non-zero Temperature Balance Theory
# ### https://arxiv.org/pdf/2202.03198.pdf
#
# ## Theory:
# ### Heider balance under disordered triadic interactions
# ### https://arxiv.org/pdf/bagherikalhor2021.pdf

# %%
def q(Q, B, J):
    a = np.exp(2*B*Q)
    b = 2*np.exp(-2*B*J*np.tanh(B*Q))
    c = np.exp(-2*B*Q)
    return (a - b + c)/(a + b + c)

def Q(y, T):
    global hist, bin_edges
    B = 1/T
    Q_ = (((bin_edges[:-1] + bin_edges[1:])/2) * hist * q(y, B, ((bin_edges[:-1] + bin_edges[1:])/2)) * (bin_edges[1] - bin_edges[0])).sum() / N
    return Q_

def P_mv(x):
    T, y = x
    x = float(optimize.fixed_point(Q, y, args=(T,), maxiter=10000))**2 + 1e-8
    return 1/(1e10*(x**2)) + x**2

# %%
df = pd.read_pickle('/home/bill/stonks/2101.09395/SP500_2012_2021.pkl')
df = df.interpolate()
df_lr = deepcopy(df.iloc[1:])
df_lr.columns = pd.MultiIndex.from_tuples([(c[0], 'Log_Return') for c in df.columns])
df_lr.iloc[0:] = np.log(df.values[1:]) - np.log(df.values[:-1])
df_lr[pd.isna(df_lr)] = 0

# %%
ws = 51
M = 2000000
N = 10000000
T = 30
opt_df = pd.DataFrame(index=df_lr.index[ws-1:], columns=['Critical_Temperature', 'Fixed_Point'])
pbar = tqdm(total=df_lr.shape[0]-ws)
for ct, idx in enumerate(range(ws, df_lr.shape[0])):
    eg_arr = df_lr.iloc[idx-ws:idx].values
    eg_arr_std = eg_arr.std(axis=0).reshape(eg_arr.shape[1], 1)
    dm_denom = pdist(eg_arr_std, lambda u, v: (u*v))
    dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
    dm[pd.isna(dm)] = 0
    dm[np.isinf(dm)] = 0
    i_s, j_s, k_s = np.random.choice(np.arange(dm.shape[0]), size=3*M).reshape(3, M)
    J = np.abs(dm[i_s, j_s] * dm[j_s, k_s] * dm[k_s,i_s])
    J = J[J!=0]
    J = np.random.choice(J, replace=False, size=1000000)
    hist, bin_edges = np.histogram(J, bins=100)
    hist = hist/hist.sum()
    sp = .01
    while Q(sp, T) > sp:
        sp += .01
    fp = float(optimize.fixed_point(Q, sp, args=(T,)))
    try:
        res = optimize.minimize(P_mv, np.array([T, fp]), options={'maxiter':10000, 'disp':False})
    except RuntimeError:
        pbar.update(1)
        continue
    opt_df.iloc[ct] = res.x
    pbar.update(1)
# Out:
#   0%|          | 0/2457 [00:00<?, ?it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#   3%|▎         | 62/2457 [00:43<44:46,  1.12s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#   4%|▎         | 87/2457 [01:21<59:33,  1.51s/it]  <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#   4%|▍         | 94/2457 [01:28<38:51,  1.01it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#   4%|▍         | 102/2457 [01:36<35:28,  1.11it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  11%|█         | 276/2457 [03:29<29:48,  1.22it/s]  <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  11%|█▏        | 280/2457 [03:32<27:52,  1.30it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  11%|█▏        | 282/2457 [03:34<31:36,  1.15it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  12%|█▏        | 283/2457 [03:35<32:12,  1.12it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  12%|█▏        | 284/2457 [03:35<31:37,  1.15it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  12%|█▏        | 305/2457 [03:49<22:45,  1.58it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  13%|█▎        | 315/2457 [03:57<32:58,  1.08it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  13%|█▎        | 326/2457 [04:10<32:33,  1.09it/s]  <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  14%|█▎        | 333/2457 [04:16<31:41,  1.12it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  14%|█▎        | 334/2457 [04:17<32:06,  1.10it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  20%|██        | 493/2457 [06:15<32:35,  1.00it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  26%|██▋       | 651/2457 [08:08<25:01,  1.20it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  29%|██▉       | 724/2457 [09:06<27:10,  1.06it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  35%|███▌      | 868/2457 [10:49<24:13,  1.09it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 875/2457 [11:00<38:58,  1.48s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 877/2457 [11:06<57:05,  2.17s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 878/2457 [11:07<54:23,  2.07s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 881/2457 [11:13<49:10,  1.87s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 884/2457 [11:22<1:10:30,  2.69s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 885/2457 [11:26<1:21:58,  3.13s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 886/2457 [11:30<1:24:19,  3.22s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▌      | 889/2457 [11:34<55:25,  2.12s/it]  <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▋      | 891/2457 [11:36<38:53,  1.49s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▋      | 893/2457 [11:41<52:49,  2.03s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  36%|███▋      | 895/2457 [11:47<1:05:02,  2.50s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 900/2457 [12:02<1:19:55,  3.08s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 903/2457 [12:08<1:01:13,  2.36s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 905/2457 [12:10<42:56,  1.66s/it]  <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 906/2457 [12:11<37:49,  1.46s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 907/2457 [12:13<41:00,  1.59s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 910/2457 [12:20<47:35,  1.85s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 911/2457 [12:23<56:57,  2.21s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  37%|███▋      | 917/2457 [12:36<43:02,  1.68s/it]  <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  39%|███▉      | 965/2457 [13:19<23:01,  1.08it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  40%|███▉      | 972/2457 [13:25<26:42,  1.08s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  40%|███▉      | 974/2457 [13:27<25:19,  1.02s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  40%|███▉      | 975/2457 [13:28<24:52,  1.01s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  40%|████      | 995/2457 [13:51<40:21,  1.66s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  41%|████      | 1000/2457 [13:58<30:24,  1.25s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  41%|████      | 1011/2457 [14:11<33:08,  1.38s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  44%|████▍     | 1086/2457 [15:12<35:57,  1.57s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  44%|████▍     | 1088/2457 [15:15<37:08,  1.63s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  45%|████▌     | 1108/2457 [15:43<23:44,  1.06s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  45%|████▌     | 1113/2457 [15:50<26:02,  1.16s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  45%|████▌     | 1116/2457 [15:54<27:13,  1.22s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  46%|████▌     | 1119/2457 [15:57<27:42,  1.24s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  51%|█████     | 1242/2457 [17:21<19:05,  1.06it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  57%|█████▋    | 1397/2457 [18:49<08:47,  2.01it/s]<ipython-input-2-75ec77c9b37f>:3: RuntimeWarning: overflow encountered in exp
#   b = 2*np.exp(-2*B*J*np.tanh(B*Q))
# <ipython-input-2-75ec77c9b37f>:5: RuntimeWarning: invalid value encountered in true_divide
#   return (a - b + c)/(a + b + c)
#  57%|█████▋    | 1399/2457 [18:53<21:39,  1.23s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  60%|█████▉    | 1465/2457 [19:27<08:07,  2.03it/s]<ipython-input-2-75ec77c9b37f>:3: RuntimeWarning: overflow encountered in exp
#   b = 2*np.exp(-2*B*J*np.tanh(B*Q))
# <ipython-input-2-75ec77c9b37f>:5: RuntimeWarning: invalid value encountered in true_divide
#   return (a - b + c)/(a + b + c)
#  60%|█████▉    | 1467/2457 [19:31<21:21,  1.29s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-2-75ec77c9b37f>:3: RuntimeWarning: overflow encountered in exp
#   b = 2*np.exp(-2*B*J*np.tanh(B*Q))
# <ipython-input-2-75ec77c9b37f>:5: RuntimeWarning: invalid value encountered in true_divide
#   return (a - b + c)/(a + b + c)
#  62%|██████▏   | 1514/2457 [20:18<21:04,  1.34s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  62%|██████▏   | 1517/2457 [20:26<33:13,  2.12s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  62%|██████▏   | 1518/2457 [20:27<31:48,  2.03s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  62%|██████▏   | 1523/2457 [20:36<25:01,  1.61s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  62%|██████▏   | 1525/2457 [20:38<22:07,  1.42s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  62%|██████▏   | 1526/2457 [20:40<22:38,  1.46s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  62%|██████▏   | 1531/2457 [20:49<27:32,  1.78s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  63%|██████▎   | 1536/2457 [20:55<24:37,  1.60s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  63%|██████▎   | 1537/2457 [20:56<22:00,  1.44s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  66%|██████▌   | 1613/2457 [21:58<07:49,  1.80it/s]<ipython-input-2-75ec77c9b37f>:3: RuntimeWarning: overflow encountered in exp
#   b = 2*np.exp(-2*B*J*np.tanh(B*Q))
# <ipython-input-2-75ec77c9b37f>:5: RuntimeWarning: invalid value encountered in true_divide
#   return (a - b + c)/(a + b + c)
#  66%|██████▋   | 1630/2457 [22:10<09:33,  1.44it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  69%|██████▉   | 1690/2457 [22:49<10:00,  1.28it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  69%|██████▉   | 1698/2457 [22:59<17:56,  1.42s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  69%|██████▉   | 1706/2457 [23:09<18:35,  1.49s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  70%|██████▉   | 1719/2457 [23:24<11:21,  1.08it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  70%|███████   | 1728/2457 [23:34<15:30,  1.28s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  70%|███████   | 1732/2457 [23:40<16:55,  1.40s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  71%|███████   | 1734/2457 [23:42<14:50,  1.23s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  71%|███████   | 1747/2457 [24:02<17:42,  1.50s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  71%|███████▏  | 1754/2457 [24:10<12:37,  1.08s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  76%|███████▌  | 1867/2457 [25:24<07:20,  1.34it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  77%|███████▋  | 1883/2457 [25:36<07:20,  1.30it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  78%|███████▊  | 1912/2457 [26:00<07:06,  1.28it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  81%|████████▏ | 2002/2457 [26:54<07:12,  1.05it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  82%|████████▏ | 2006/2457 [27:02<15:11,  2.02s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  82%|████████▏ | 2008/2457 [27:05<13:43,  1.83s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  82%|████████▏ | 2022/2457 [27:19<10:52,  1.50s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  83%|████████▎ | 2043/2457 [28:03<11:00,  1.60s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  83%|████████▎ | 2047/2457 [28:19<27:09,  3.97s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▎ | 2055/2457 [28:33<15:01,  2.24s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▎ | 2056/2457 [28:34<13:30,  2.02s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2063/2457 [28:47<12:25,  1.89s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2067/2457 [28:53<10:45,  1.65s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2070/2457 [28:58<09:49,  1.52s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2071/2457 [28:59<09:09,  1.42s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2072/2457 [29:00<08:34,  1.34s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2074/2457 [29:07<17:29,  2.74s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2075/2457 [29:09<14:51,  2.33s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  84%|████████▍ | 2076/2457 [29:14<19:14,  3.03s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  85%|████████▍ | 2077/2457 [29:15<15:30,  2.45s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  85%|████████▌ | 2093/2457 [29:49<10:07,  1.67s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  86%|████████▌ | 2101/2457 [30:02<13:26,  2.27s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  86%|████████▌ | 2103/2457 [30:07<14:08,  2.40s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  86%|████████▌ | 2108/2457 [30:17<13:23,  2.30s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  86%|████████▌ | 2110/2457 [30:19<09:03,  1.57s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  86%|████████▌ | 2114/2457 [30:24<06:37,  1.16s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  86%|████████▋ | 2120/2457 [30:32<07:36,  1.35s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  86%|████████▋ | 2123/2457 [30:36<08:13,  1.48s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  89%|████████▊ | 2176/2457 [31:17<04:35,  1.02it/s]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
#  89%|████████▉ | 2195/2457 [31:34<05:02,  1.16s/it]<ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: divide by zero encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# <ipython-input-4-2bd3b7ab84bc>:11: RuntimeWarning: invalid value encountered in true_divide
#   dm = (np.tensordot(eg_arr, eg_arr, axes=(0,0))/squareform(dm_denom))
# 100%|██████████| 2457/2457 [34:42<00:00,  1.42it/s]

# %%
opt_df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
spy_df = yf.Ticker("SPY").history(period="max")
spy_df = spy_df.loc[spy_df.index.intersection(opt_df.index)]['Close']

# %%
fig = plt.figure(figsize=(30,10))
X = np.arange(spy_df.shape[0])
Y = spy_df.values
plt.scatter(X, Y, c=-(opt_df['Critical_Temperature'].values)**.5, cmap='RdYlGn')
